# %%
pip install ultralytics

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.124 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 24.2/78.2 GB disk)

# %%
# !yolo task=detect mode=train epochs=224 data=/content/drive/MyDrive/drive/yolov8/yolo_data/dataset.yaml model=/content/drive/MyDrive/drive/yolov8/output/runs/detect/train/weights/yolov8m_custom.pt imgsz=640
# Out:
# Ultralytics YOLOv8.0.124 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/drive/yolov8/output/runs/detect/train/weights/yolov8m_custom.pt conf=0.77 source='/content/drive/MyDrive/drive/yolov8/t_videos/ऑटो रिक्शा गिर गई गटर में मस्ती एक्सप्रेस का मजेदार क्लाइमेक्स सीन.mp4'
